# %% [markdown]
# # Latency analysis
#
# First pass.

# %%
import pandas as pd
df = pd.read_csv('big.csv')
df.describe()
# Out:
# count  4000
# mean    452.1

# %%
df.groupby("service").latency_ms.mean().plot()
# Out:
# <Axes: >
